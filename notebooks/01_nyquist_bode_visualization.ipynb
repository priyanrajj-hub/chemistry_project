# %% [markdown]
# # 01. Nyquist & Bode Visualization
# This notebook demonstrates how the software pipeline processes the 860 SPS real-world signals into complex impedance values (Z) for the Nyquist loop.
